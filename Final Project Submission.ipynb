# %%
Capstone Project - The Battle of Neighborhoods

# %% [markdown]
# Introduction
#
#
# I'm a resident of New York and always wanted to explore the restaurant business around New York. I am interested to know which cuisine based restaurant would be successful and in which neighbourhood.

# %% [markdown]
# Data
#
#
# New York City data:
#         https://cocl.us/new_york_dataset
#
# Neighbourhood Exploration API:
#          Fousquare API
#
# Visualising the boundaries:
#          https://data.cityofnewyork.us/City-Government/Borough-Boundaries/tqmj-j8zm

# %% [markdown]
# Approach
#
#
# Collect the new york city data from https://cocl.us/new_york_dataset
# Using FourSquare API we will find all venues for each neighborhood.
# Find rating , tips and like count for each Resturants using FourSquare API.
# Using rating for each resturant type, we will sort that data.
# Visualize the Ranking of neighborhoods using folium library(python)

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import requests
from bs4 import BeautifulSoup
import os
import folium # map rendering library
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
#import geocoder


# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline


print('Libraries imported.')
# Out:
# Libraries imported.

# %%
import time

# %%
os.environ['CLIENT_ID']='J35SCFKMV50ASNIYVGRDBW0MWDXLVF3OPH02ZSY3TUVA1FUE'
os.environ['CLIENT_SECRET']='SVH00YZHMK0VC01C1ZWHOJZ30LEIXR25LUQXNJLIBWKXW2UF'

# %%
os.environ
# Out:
# environ{'LC_ALL': 'C.UTF-8',
#         'HADOOP_HOME': '/home/jupyterlab/hadoop-2.7.3',
#         'LANG': 'C.UTF-8',
#         'HOSTNAME': 'a2d8aae6ce42',
#         'OLDPWD': '/home/jupyterlab',
#         'SPARK_PACKAGE': 'spark-2.3.1-bin-without-hadoop',
#         'NB_UID': '1000',
#         'SPARK_VERSION': '2.3.1',
#         'JAVA_HOME': '/usr/jdk1.8.0_131',
#         'CONDA_DIR': '/home/jupyterlab/conda',
#         'PYTHONIOENCODING': 'UTF-8',
#         'PROJ_LIB': '/home/jupyterlab/conda/share/proj',
#         'USER': 'jupyterlab',
#         'PYTHONHASHSEED': '0',
#         'PWD': '/resources',
#         'HOME': '/home/jupyterlab',
#         'TUTORIALS_GIT_URL': 'https://github.com/cognitive-class/jupyterlab-tutorials.git',
#         'SHOWCASE_URL': 'https://showcase.cognitiveclass.ai',
#         'ANACONDA_VERSION': '5.3.1',
#         '_SPARK_CMD_USAGE': 'Usage: ./bin/pyspark [options]',
#         'HADOOP_CONF_DIR': '/home/jupyterlab/hadoop-2.7.3/etc/hadoop',
#         'SPARK_SCALA_VERSION': '2.12',
#         'SPARK_HOME': '/home/jupyterlab/spark-2.3.1',
#         'HADOOP_VERSION': '2.7.3',
#         'MAIL': '/var/mail/jupyterlab',
#         'GITHUB_CLIENT_SECRET': 'ca2bc8b909c3702c3aed959e4d279f72dc59dcb2',
#         'SHELL': '/bin/bash',
#         'SHOWCASE_ADMIN_USERNAME': 'admin',
#         'RESOURCES_GID': '2000',
#         'PYSPARK_DRIVER_PYTHON': '/home/jupyterlab/conda/bin/jupyter',
#         'PYTHONSTARTUP': '/home/jupyterlab/spark-2.3.1/python/pyspark/shell.py',
#         'SPARK_ENV_LOADED': '1',
#         'SHLVL': '2',
#         'LANGUAGE': 'en_US:en',
#         'PYTHONPATH': '/home/jupyterlab/spark-2.3.1/python/lib/py4j-0.10.7-src.zip:/home/jupyterlab/spark-2.3.1/python/:',
#         'PYSPARK_DRIVER_PYTHON_OPTS': 'lab --notebook-dir=/resources --ip=0.0.0.0 --port=8088 --no-browser --config=/home/jupyterlab/.jupyter/jupyter_notebook_config.py',
#         'LOGNAME': 'jupyterlab',
#         'PIP_DISABLE_PIP_VERSION_CHECK': '1',
#         'SPARK_CONF_DIR': '/home/jupyterlab/spark-2.3.1/conf',
#         'PYSPARK_PYTHON': '/home/jupyterlab/conda/bin/python3',
#         'PATH': '/home/jupyterlab/conda/bin:/usr/local/bin:/usr/bin:/bin:/usr/local/games:/usr/games',
#         'SPARK_DIST_CLASSPATH': '/home/jupyterlab/hadoop-2.7.3/etc/hadoop/*:/home/jupyterlab/hadoop-2.7.3/share/hadoop/common/lib/*:/home/jupyterlab/hadoop-2.7.3/share/hadoop/common/*:/home/jupyterlab/hadoop-2.7.3/share/hadoop/hdfs/*:/home/jupyterlab/hadoop-2.7.3/share/hadoop/hdfs/lib/*:/home/jupyterlab/hadoop-2.7.3/share/hadoop/hdfs/*:/home/jupyterlab/hadoop-2.7.3/share/hadoop/yarn/lib/*:/home/jupyterlab/hadoop-2.7.3/share/hadoop/yarn/*:/home/jupyterlab/hadoop-2.7.3/share/hadoop/mapreduce/lib/*:/home/jupyterlab/hadoop-2.7.3/share/hadoop/mapreduce/*:/home/jupyterlab/hadoop-2.7.3/share/hadoop/tools/lib/*',
#         'GITHUB_CLIENT_ID': 'd6c165b3918bec876774',
#         'SHOWCASE_ADMIN_PASSWORD': '4f9f8d53fad3e688510eef6a007ab30324540427',
#         'OLD_PYTHONSTARTUP': '',
#         'PYSPARK_SUBMIT_ARGS': '"--name" "PySparkShell" "pyspark-shell"',
#         'JPY_PARENT_PID': '29',
#         'TERM': 'xterm-color',
#         'CLICOLOR': '1',
#         'PAGER': 'cat',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://ipykernel.pylab.backend_inline',
#         'CLIENT_ID': 'J35SCFKMV50ASNIYVGRDBW0MWDXLVF3OPH02ZSY3TUVA1FUE',
#         'CLIENT_SECRET': 'SVH00YZHMK0VC01C1ZWHOJZ30LEIXR25LUQXNJLIBWKXW2UF'}

# %%
def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude

# %%
def get_venues(lat,lng):
    
    #set variables
    radius=1000
    LIMIT=100
    CLIENT_ID = os.environ['CLIENT_ID'] # your Foursquare ID
    CLIENT_SECRET = os.environ['CLIENT_SECRET'] # your Foursquare Secret
    VERSION = '20180605' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
    #print(url)
    # get all the data
    results = requests.get(url).json()
    #print(results)
    venue_data=results['response']['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
        
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
#get_venues(40.894705,-73.847201)

# %%
def get_venue_details(venue_id):
        
    CLIENT_ID = os.environ['CLIENT_ID'] # your Foursquare ID
    CLIENT_SECRET = os.environ['CLIENT_SECRET'] # your Foursquare Secret
    VERSION = '20190605' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET,
            VERSION)
    
    #print(url)
    # get all the data
    try:
        results = requests.get(url).json()
    except:
        results=[]
        raise 
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
        
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
def get_new_york_data():
    url='https://cocl.us/new_york_dataset'
    resp=requests.get(url).json()
    # all data is present in features label
    features=resp['features']
    
    # define the dataframe columns
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    # instantiate the dataframe
    new_york_data = pd.DataFrame(columns=column_names)
    
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
    
        new_york_data = new_york_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                             'Longitude': neighborhood_lon}, ignore_index=True)
    
    return new_york_data

# %%
new_york_data=get_new_york_data()

# %%
new_york_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
new_york_data.shape
# Out:
# (306, 4)

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Neighborhood for each Borough in New York City')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('No.of Neighborhood', fontsize=15)
#giving a bar plot
new_york_data.groupby('Borough')['Neighborhood'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
new_york_data.groupby('Borough')['Neighborhood'].count()
# Out:
# Borough
# Bronx            52
# Brooklyn         70
# Manhattan        40
# Queens           81
# Staten Island    63
# Name: Neighborhood, dtype: int64

# %%
column_names=['Borough', 'Neighborhood', 'Category', 'ID','Name']
rest_ny=pd.DataFrame(columns=column_names)
count=1
for row in new_york_data.values.tolist():
    Borough, Neighborhood,  Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    resturants=venues[venues['Category'].str.contains('Restaurant')]   
    print('(',count,'/',len(new_york_data),')', 'Resturants in '+Neighborhood+', '+Borough+':'+str(len(resturants)))
    #print(resturants)
    #break
    time.sleep(1)
    for resturant_detail in resturants.values.tolist():
        category, id, name =resturant_detail
        rest_ny = rest_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood,  
                                                'Category' : category,  
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 306 ) Resturants in Wakefield, Bronx:11
# ( 2 / 306 ) Resturants in Co-op City, Bronx:13
# ( 3 / 306 ) Resturants in Eastchester, Bronx:13
# ( 4 / 306 ) Resturants in Fieldston, Bronx:6
# ( 5 / 306 ) Resturants in Riverdale, Bronx:10
# ( 6 / 306 ) Resturants in Kingsbridge, Bronx:20
# ( 7 / 306 ) Resturants in Marble Hill, Manhattan:14
# ( 8 / 306 ) Resturants in Woodlawn, Bronx:7
# ( 9 / 306 ) Resturants in Norwood, Bronx:15
# ( 10 / 306 ) Resturants in Williamsbridge, Bronx:13
# ( 11 / 306 ) Resturants in Baychester, Bronx:16
# ( 12 / 306 ) Resturants in Pelham Parkway, Bronx:9
# ( 13 / 306 ) Resturants in City Island, Bronx:15
# ( 14 / 306 ) Resturants in Bedford Park, Bronx:9
# ( 15 / 306 ) Resturants in University Heights, Bronx:11
# ( 16 / 306 ) Resturants in Morris Heights, Bronx:13
# ( 17 / 306 ) Resturants in Fordham, Bronx:24
# ( 18 / 306 ) Resturants in East Tremont, Bronx:8
# ( 19 / 306 ) Resturants in West Farms, Bronx:4
# ( 20 / 306 ) Resturants in High  Bridge, Bronx:3
# ( 21 / 306 ) Resturants in Melrose, Bronx:22
# ( 22 / 306 ) Resturants in Mott Haven, Bronx:14
# ( 23 / 306 ) Resturants in Port Morris, Bronx:8
# ( 24 / 306 ) Resturants in Longwood, Bronx:15
# ( 25 / 306 ) Resturants in Hunts Point, Bronx:5
# ( 26 / 306 ) Resturants in Morrisania, Bronx:16
# ( 27 / 306 ) Resturants in Soundview, Bronx:10
# ( 28 / 306 ) Resturants in Clason Point, Bronx:0
# ( 29 / 306 ) Resturants in Throgs Neck, Bronx:10
# ( 30 / 306 ) Resturants in Country Club, Bronx:13
# ( 31 / 306 ) Resturants in Parkchester, Bronx:26
# ( 32 / 306 ) Resturants in Westchester Square, Bronx:15
# ( 33 / 306 ) Resturants in Van Nest, Bronx:12
# ( 34 / 306 ) Resturants in Morris Park, Bronx:21
# ( 35 / 306 ) Resturants in Belmont, Bronx:25
# ( 36 / 306 ) Resturants in Spuyten Duyvil, Bronx:10
# ( 37 / 306 ) Resturants in North Riverdale, Bronx:8
# ( 38 / 306 ) Resturants in Pelham Bay, Bronx:15
# ( 39 / 306 ) Resturants in Schuylerville, Bronx:14
# ( 40 / 306 ) Resturants in Edgewater Park, Bronx:13
# ( 41 / 306 ) Resturants in Castle Hill, Bronx:7
# ( 42 / 306 ) Resturants in Olinville, Bronx:11
# ( 43 / 306 ) Resturants in Pelham Gardens, Bronx:7
# ( 44 / 306 ) Resturants in Concourse, Bronx:14
# ( 45 / 306 ) Resturants in Unionport, Bronx:24
# ( 46 / 306 ) Resturants in Edenwald, Bronx:9
# ( 47 / 306 ) Resturants in Bay Ridge, Brooklyn:34
# ( 48 / 306 ) Resturants in Bensonhurst, Brooklyn:28
# ( 49 / 306 ) Resturants in Sunset Park, Brooklyn:39
# ( 50 / 306 ) Resturants in Greenpoint, Brooklyn:20
# ( 51 / 306 ) Resturants in Gravesend, Brooklyn:7
# ( 52 / 306 ) Resturants in Brighton Beach, Brooklyn:22
# ( 53 / 306 ) Resturants in Sheepshead Bay, Brooklyn:33
# ( 54 / 306 ) Resturants in Manhattan Terrace, Brooklyn:19
# ( 55 / 306 ) Resturants in Flatbush, Brooklyn:35
# ( 56 / 306 ) Resturants in Crown Heights, Brooklyn:20
# ( 57 / 306 ) Resturants in East Flatbush, Brooklyn:6
# ( 58 / 306 ) Resturants in Kensington, Brooklyn:21
# ( 59 / 306 ) Resturants in Windsor Terrace, Brooklyn:20
# ( 60 / 306 ) Resturants in Prospect Heights, Brooklyn:29
# ( 61 / 306 ) Resturants in Brownsville, Brooklyn:14
# ( 62 / 306 ) Resturants in Williamsburg, Brooklyn:28
# ( 63 / 306 ) Resturants in Bushwick, Brooklyn:26
# ( 64 / 306 ) Resturants in Bedford Stuyvesant, Brooklyn:22
# ( 65 / 306 ) Resturants in Brooklyn Heights, Brooklyn:24
# ( 66 / 306 ) Resturants in Cobble Hill, Brooklyn:24
# ( 67 / 306 ) Resturants in Carroll Gardens, Brooklyn:20
# ( 68 / 306 ) Resturants in Red Hook, Brooklyn:10
# ( 69 / 306 ) Resturants in Gowanus, Brooklyn:22
# ( 70 / 306 ) Resturants in Fort Greene, Brooklyn:28
# ( 71 / 306 ) Resturants in Park Slope, Brooklyn:24
# ( 72 / 306 ) Resturants in Cypress Hills, Brooklyn:12
# ( 73 / 306 ) Resturants in East New York, Brooklyn:3
# ( 74 / 306 ) Resturants in Starrett City, Brooklyn:7
# ( 75 / 306 ) Resturants in Canarsie, Brooklyn:6
# ( 76 / 306 ) Resturants in Flatlands, Brooklyn:11
# ( 77 / 306 ) Resturants in Mill Island, Brooklyn:3
# ( 78 / 306 ) Resturants in Manhattan Beach, Brooklyn:23
# ( 79 / 306 ) Resturants in Coney Island, Brooklyn:9
# ( 80 / 306 ) Resturants in Bath Beach, Brooklyn:32
# ( 81 / 306 ) Resturants in Borough Park, Brooklyn:6
# ( 82 / 306 ) Resturants in Dyker Heights, Brooklyn:21
# ( 83 / 306 ) Resturants in Gerritsen Beach, Brooklyn:13
# ( 84 / 306 ) Resturants in Marine Park, Brooklyn:12
# ( 85 / 306 ) Resturants in Clinton Hill, Brooklyn:38
# ( 86 / 306 ) Resturants in Sea Gate, Brooklyn:0
# ( 87 / 306 ) Resturants in Downtown, Brooklyn:19
# ( 88 / 306 ) Resturants in Boerum Hill, Brooklyn:18
# ( 89 / 306 ) Resturants in Prospect Lefferts Gardens, Brooklyn:32
# ( 90 / 306 ) Resturants in Ocean Hill, Brooklyn:15
# ( 91 / 306 ) Resturants in City Line, Brooklyn:21
# ( 92 / 306 ) Resturants in Bergen Beach, Brooklyn:2
# ( 93 / 306 ) Resturants in Midwood, Brooklyn:11
# ( 94 / 306 ) Resturants in Prospect Park South, Brooklyn:33
# ( 95 / 306 ) Resturants in Georgetown, Brooklyn:19
# ( 96 / 306 ) Resturants in East Williamsburg, Brooklyn:21
# ( 97 / 306 ) Resturants in North Side, Brooklyn:27
# ( 98 / 306 ) Resturants in South Side, Brooklyn:29
# ( 99 / 306 ) Resturants in Ocean Parkway, Brooklyn:26
# ( 100 / 306 ) Resturants in Fort Hamilton, Brooklyn:25
# ( 101 / 306 ) Resturants in Chinatown, Manhattan:27
# ( 102 / 306 ) Resturants in Washington Heights, Manhattan:34
# ( 103 / 306 ) Resturants in Inwood, Manhattan:32
# ( 104 / 306 ) Resturants in Hamilton Heights, Manhattan:34
# ( 105 / 306 ) Resturants in Manhattanville, Manhattan:34
# ( 106 / 306 ) Resturants in Central Harlem, Manhattan:35
# ( 107 / 306 ) Resturants in East Harlem, Manhattan:29
# ( 108 / 306 ) Resturants in Upper East Side, Manhattan:25
# ( 109 / 306 ) Resturants in Yorkville, Manhattan:30
# ( 110 / 306 ) Resturants in Lenox Hill, Manhattan:30
# ( 111 / 306 ) Resturants in Roosevelt Island, Manhattan:24
# ( 112 / 306 ) Resturants in Upper West Side, Manhattan:32
# ( 113 / 306 ) Resturants in Lincoln Square, Manhattan:15
# ( 114 / 306 ) Resturants in Clinton, Manhattan:20
# ( 115 / 306 ) Resturants in Midtown, Manhattan:21
# ( 116 / 306 ) Resturants in Murray Hill, Manhattan:32
# ( 117 / 306 ) Resturants in Chelsea, Manhattan:21
# ( 118 / 306 ) Resturants in Greenwich Village, Manhattan:25
# ( 119 / 306 ) Resturants in East Village, Manhattan:31
# ( 120 / 306 ) Resturants in Lower East Side, Manhattan:31
# ( 121 / 306 ) Resturants in Tribeca, Manhattan:25
# ( 122 / 306 ) Resturants in Little Italy, Manhattan:21
# ( 123 / 306 ) Resturants in Soho, Manhattan:26
# ( 124 / 306 ) Resturants in West Village, Manhattan:35
# ( 125 / 306 ) Resturants in Manhattan Valley, Manhattan:31
# ( 126 / 306 ) Resturants in Morningside Heights, Manhattan:34
# ( 127 / 306 ) Resturants in Gramercy, Manhattan:38
# ( 128 / 306 ) Resturants in Battery Park City, Manhattan:7
# ( 129 / 306 ) Resturants in Financial District, Manhattan:17
# ( 130 / 306 ) Resturants in Astoria, Queens:27
# ( 131 / 306 ) Resturants in Woodside, Queens:43
# ( 132 / 306 ) Resturants in Jackson Heights, Queens:57
# ( 133 / 306 ) Resturants in Elmhurst, Queens:61
# ( 134 / 306 ) Resturants in Howard Beach, Queens:18
# ( 135 / 306 ) Resturants in Corona, Queens:22
# ( 136 / 306 ) Resturants in Forest Hills, Queens:34
# ( 137 / 306 ) Resturants in Kew Gardens, Queens:10
# ( 138 / 306 ) Resturants in Richmond Hill, Queens:21
# ( 139 / 306 ) Resturants in Flushing, Queens:52
# ( 140 / 306 ) Resturants in Long Island City, Queens:18
# ( 141 / 306 ) Resturants in Sunnyside, Queens:32
# ( 142 / 306 ) Resturants in East Elmhurst, Queens:14
# ( 143 / 306 ) Resturants in Maspeth, Queens:7
# ( 144 / 306 ) Resturants in Ridgewood, Queens:29
# ( 145 / 306 ) Resturants in Glendale, Queens:10
# ( 146 / 306 ) Resturants in Rego Park, Queens:27
# ( 147 / 306 ) Resturants in Woodhaven, Queens:20
# ( 148 / 306 ) Resturants in Ozone Park, Queens:13
# ( 149 / 306 ) Resturants in South Ozone Park, Queens:11
# ( 150 / 306 ) Resturants in College Point, Queens:11
# ( 151 / 306 ) Resturants in Whitestone, Queens:13
# ( 152 / 306 ) Resturants in Bayside, Queens:33
# ( 153 / 306 ) Resturants in Auburndale, Queens:32
# ( 154 / 306 ) Resturants in Little Neck, Queens:25
# ( 155 / 306 ) Resturants in Douglaston, Queens:23
# ( 156 / 306 ) Resturants in Glen Oaks, Queens:12
# ( 157 / 306 ) Resturants in Bellerose, Queens:4
# ( 158 / 306 ) Resturants in Kew Gardens Hills, Queens:11
# ( 159 / 306 ) Resturants in Fresh Meadows, Queens:22
# ( 160 / 306 ) Resturants in Briarwood, Queens:25
# ( 161 / 306 ) Resturants in Jamaica Center, Queens:30
# ( 162 / 306 ) Resturants in Oakland Gardens, Queens:15
# ( 163 / 306 ) Resturants in Queens Village, Queens:4
# ( 164 / 306 ) Resturants in Hollis, Queens:4
# ( 165 / 306 ) Resturants in South Jamaica, Queens:1
# ( 166 / 306 ) Resturants in St. Albans, Queens:8
# ( 167 / 306 ) Resturants in Rochdale, Queens:7
# ( 168 / 306 ) Resturants in Springfield Gardens, Queens:5
# ( 169 / 306 ) Resturants in Cambria Heights, Queens:8
# ( 170 / 306 ) Resturants in Rosedale, Queens:10
# ( 171 / 306 ) Resturants in Far Rockaway, Queens:6
# ( 172 / 306 ) Resturants in Broad Channel, Queens:1
# ( 173 / 306 ) Resturants in Breezy Point, Queens:1
# ( 174 / 306 ) Resturants in Steinway, Queens:29
# ( 175 / 306 ) Resturants in Beechhurst, Queens:12
# ( 176 / 306 ) Resturants in Bay Terrace, Queens:7
# ( 177 / 306 ) Resturants in Edgemere, Queens:2
# ( 178 / 306 ) Resturants in Arverne, Queens:2
# ( 179 / 306 ) Resturants in Rockaway Beach, Queens:21
# ( 180 / 306 ) Resturants in Neponsit, Queens:3
# ( 181 / 306 ) Resturants in Murray Hill, Queens:41
# ( 182 / 306 ) Resturants in Floral Park, Queens:20
# ( 183 / 306 ) Resturants in Holliswood, Queens:10
# ( 184 / 306 ) Resturants in Jamaica Estates, Queens:13
# ( 185 / 306 ) Resturants in Queensboro Hill, Queens:21
# ( 186 / 306 ) Resturants in Hillcrest, Queens:19
# ( 187 / 306 ) Resturants in Ravenswood, Queens:38
# ( 188 / 306 ) Resturants in Lindenwood, Queens:9
# ( 189 / 306 ) Resturants in Laurelton, Queens:14
# ( 190 / 306 ) Resturants in Lefrak City, Queens:26
# ( 191 / 306 ) Resturants in Belle Harbor, Queens:3
# ( 192 / 306 ) Resturants in Rockaway Park, Queens:7
# ( 193 / 306 ) Resturants in Somerville, Queens:2
# ( 194 / 306 ) Resturants in Brookville, Queens:3
# ( 195 / 306 ) Resturants in Bellaire, Queens:11
# ( 196 / 306 ) Resturants in North Corona, Queens:22
# ( 197 / 306 ) Resturants in Forest Hills Gardens, Queens:30
# ( 198 / 306 ) Resturants in St. George, Staten Island:12
# ( 199 / 306 ) Resturants in New Brighton, Staten Island:14
# ( 200 / 306 ) Resturants in Stapleton, Staten Island:8
# ( 201 / 306 ) Resturants in Rosebank, Staten Island:10
# ( 202 / 306 ) Resturants in West Brighton, Staten Island:10
# ( 203 / 306 ) Resturants in Grymes Hill, Staten Island:3
# ( 204 / 306 ) Resturants in Todt Hill, Staten Island:0
# ( 205 / 306 ) Resturants in South Beach, Staten Island:1
# ( 206 / 306 ) Resturants in Port Richmond, Staten Island:9
# ( 207 / 306 ) Resturants in Mariner's Harbor, Staten Island:12
# ( 208 / 306 ) Resturants in Port Ivory, Staten Island:0
# ( 209 / 306 ) Resturants in Castleton Corners, Staten Island:8
# ( 210 / 306 ) Resturants in New Springville, Staten Island:3
# ( 211 / 306 ) Resturants in Travis, Staten Island:3
# ( 212 / 306 ) Resturants in New Dorp, Staten Island:21
# ( 213 / 306 ) Resturants in Oakwood, Staten Island:2
# ( 214 / 306 ) Resturants in Great Kills, Staten Island:15
# ( 215 / 306 ) Resturants in Eltingville, Staten Island:11
# ( 216 / 306 ) Resturants in Annadale, Staten Island:2
# ( 217 / 306 ) Resturants in Woodrow, Staten Island:3
# ( 218 / 306 ) Resturants in Tottenville, Staten Island:5
# ( 219 / 306 ) Resturants in Tompkinsville, Staten Island:14
# ( 220 / 306 ) Resturants in Silver Lake, Staten Island:3
# ( 221 / 306 ) Resturants in Sunnyside, Staten Island:4
# ( 222 / 306 ) Resturants in Ditmas Park, Brooklyn:33
# ( 223 / 306 ) Resturants in Wingate, Brooklyn:16
# ( 224 / 306 ) Resturants in Rugby, Brooklyn:17
# ( 225 / 306 ) Resturants in Park Hill, Staten Island:5
# ( 226 / 306 ) Resturants in Westerleigh, Staten Island:17
# ( 227 / 306 ) Resturants in Graniteville, Staten Island:15
# ( 228 / 306 ) Resturants in Arlington, Staten Island:5
# ( 229 / 306 ) Resturants in Arrochar, Staten Island:5
# ( 230 / 306 ) Resturants in Grasmere, Staten Island:12
# ( 231 / 306 ) Resturants in Old Town, Staten Island:19
# ( 232 / 306 ) Resturants in Dongan Hills, Staten Island:21
# ( 233 / 306 ) Resturants in Midland Beach, Staten Island:12
# ( 234 / 306 ) Resturants in Grant City, Staten Island:24
# ( 235 / 306 ) Resturants in New Dorp Beach, Staten Island:11
# ( 236 / 306 ) Resturants in Bay Terrace, Staten Island:11
# ( 237 / 306 ) Resturants in Huguenot, Staten Island:1
# ( 238 / 306 ) Resturants in Pleasant Plains, Staten Island:2
# ( 239 / 306 ) Resturants in Butler Manor, Staten Island:1
# ( 240 / 306 ) Resturants in Charleston, Staten Island:10
# ( 241 / 306 ) Resturants in Rossville, Staten Island:1
# ( 242 / 306 ) Resturants in Arden Heights, Staten Island:3
# ( 243 / 306 ) Resturants in Greenridge, Staten Island:5
# ( 244 / 306 ) Resturants in Heartland Village, Staten Island:5
# ( 245 / 306 ) Resturants in Chelsea, Staten Island:3
# ( 246 / 306 ) Resturants in Bloomfield, Staten Island:0
# ( 247 / 306 ) Resturants in Bulls Head, Staten Island:12
# ( 248 / 306 ) Resturants in Carnegie Hill, Manhattan:21
# ( 249 / 306 ) Resturants in Noho, Manhattan:39
# ( 250 / 306 ) Resturants in Civic Center, Manhattan:23
# ( 251 / 306 ) Resturants in Midtown South, Manhattan:33
# ( 252 / 306 ) Resturants in Richmond Town, Staten Island:7
# ( 253 / 306 ) Resturants in Shore Acres, Staten Island:9
# ( 254 / 306 ) Resturants in Clifton, Staten Island:11
# ( 255 / 306 ) Resturants in Concord, Staten Island:9
# ( 256 / 306 ) Resturants in Emerson Hill, Staten Island:4
# ( 257 / 306 ) Resturants in Randall Manor, Staten Island:8
# ( 258 / 306 ) Resturants in Howland Hook, Staten Island:1
# ( 259 / 306 ) Resturants in Elm Park, Staten Island:20
# ( 260 / 306 ) Resturants in Remsen Village, Brooklyn:21
# ( 261 / 306 ) Resturants in New Lots, Brooklyn:14
# ( 262 / 306 ) Resturants in Paerdegat Basin, Brooklyn:7
# ( 263 / 306 ) Resturants in Mill Basin, Brooklyn:15
# ( 264 / 306 ) Resturants in Jamaica Hills, Queens:27
# ( 265 / 306 ) Resturants in Utopia, Queens:23
# ( 266 / 306 ) Resturants in Pomonok, Queens:10
# ( 267 / 306 ) Resturants in Astoria Heights, Queens:13
# ( 268 / 306 ) Resturants in Claremont Village, Bronx:2
# ( 269 / 306 ) Resturants in Concourse Village, Bronx:19
# ( 270 / 306 ) Resturants in Mount Eden, Bronx:11
# ( 271 / 306 ) Resturants in Mount Hope, Bronx:14
# ( 272 / 306 ) Resturants in Sutton Place, Manhattan:29
# ( 273 / 306 ) Resturants in Hunters Point, Queens:28
# ( 274 / 306 ) Resturants in Turtle Bay, Manhattan:38
# ( 275 / 306 ) Resturants in Tudor City, Manhattan:38
# ( 276 / 306 ) Resturants in Stuyvesant Town, Manhattan:22
# ( 277 / 306 ) Resturants in Flatiron, Manhattan:27
# ( 278 / 306 ) Resturants in Sunnyside Gardens, Queens:40
# ( 279 / 306 ) Resturants in Blissville, Queens:14
# ( 280 / 306 ) Resturants in Fulton Ferry, Brooklyn:18
# ( 281 / 306 ) Resturants in Vinegar Hill, Brooklyn:10
# ( 282 / 306 ) Resturants in Weeksville, Brooklyn:23
# ( 283 / 306 ) Resturants in Broadway Junction, Brooklyn:7
# ( 284 / 306 ) Resturants in Dumbo, Brooklyn:14
# ( 285 / 306 ) Resturants in Manor Heights, Staten Island:6
# ( 286 / 306 ) Resturants in Willowbrook, Staten Island:7
# ( 287 / 306 ) Resturants in Sandy Ground, Staten Island:3
# ( 288 / 306 ) Resturants in Egbertville, Staten Island:3
# ( 289 / 306 ) Resturants in Roxbury, Queens:1
# ( 290 / 306 ) Resturants in Homecrest, Brooklyn:27
# ( 291 / 306 ) Resturants in Middle Village, Queens:8
# ( 292 / 306 ) Resturants in Prince's Bay, Staten Island:1
# ( 293 / 306 ) Resturants in Lighthouse Hill, Staten Island:2
# ( 294 / 306 ) Resturants in Richmond Valley, Staten Island:14
# ( 295 / 306 ) Resturants in Malba, Queens:7
# ( 296 / 306 ) Resturants in Highland Park, Brooklyn:8
# ( 297 / 306 ) Resturants in Madison, Brooklyn:12
# ( 298 / 306 ) Resturants in Bronxdale, Bronx:15
# ( 299 / 306 ) Resturants in Allerton, Bronx:13
# ( 300 / 306 ) Resturants in Kingsbridge Heights, Bronx:8
# ( 301 / 306 ) Resturants in Erasmus, Brooklyn:21
# ( 302 / 306 ) Resturants in Hudson Yards, Manhattan:20
# ( 303 / 306 ) Resturants in Hammels, Queens:7
# ( 304 / 306 ) Resturants in Bayswater, Queens:1
# ( 305 / 306 ) Resturants in Queensbridge, Queens:19
# ( 306 / 306 ) Resturants in Fox Hills, Staten Island:5

# %%
rest_ny.to_csv("Boroughs_neighbourhoods_NY.csv")

rest_ny.shape
rest_ny.head()
# Out:
#   Borough Neighborhood                  Category  \
# 0   Bronx    Wakefield  4d375ce799fe8eec99fd2355
# 1   Bronx    Wakefield  4c9e50e38afca09379b2ff15
# 2   Bronx    Wakefield  4c10f6aece57c92804a682d2
# 3   Bronx    Wakefield  508af256e4b0578944c87392
# 4   Bronx    Wakefield  55bff8a5498e67af2457ca92
#
#                                         ID                             Name
# 0                       Ripe Kitchen & Bar             Caribbean Restaurant
# 1                          Ali's Roti Shop             Caribbean Restaurant
# 2              Jackie's West Indian Bakery             Caribbean Restaurant
# 3  Cooler Runnings Jamaican Restaurant Inc             Caribbean Restaurant
# 4                        Paula's Soul Cafe  Southern / Soul Food Restaurant

# %%
rest_ny = pd.read_csv("Boroughs_neighbourhoods_NY.csv")
rest_ny.head()
rest_ny.set_index("Unnamed: 0")
rest_ny.reset_index()

# %%
#rest_ny.reindex()

# %%
rest_ny = rest_ny[['Borough','Neighborhood','Category','ID','Name']]
rest_ny.head()
# Out:
#   Borough Neighborhood                  Category  \
# 0   Bronx    Wakefield  4d375ce799fe8eec99fd2355
# 1   Bronx    Wakefield  4c9e50e38afca09379b2ff15
# 2   Bronx    Wakefield  4c10f6aece57c92804a682d2
# 3   Bronx    Wakefield  508af256e4b0578944c87392
# 4   Bronx    Wakefield  55bff8a5498e67af2457ca92
#
#                                         ID                             Name
# 0                       Ripe Kitchen & Bar             Caribbean Restaurant
# 1                          Ali's Roti Shop             Caribbean Restaurant
# 2              Jackie's West Indian Bakery             Caribbean Restaurant
# 3  Cooler Runnings Jamaican Restaurant Inc             Caribbean Restaurant
# 4                        Paula's Soul Cafe  Southern / Soul Food Restaurant

# %%
rest_ny.groupby(['Borough'])['Category'].count()
# Out:
# Borough
# Bronx             646
# Brooklyn         1332
# Manhattan        1100
# Queens           1400
# Staten Island     483
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Resturants for each Borough in New York City')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('No.of Resturants', fontsize=15)
#giving a bar plot
rest_ny.groupby('Borough')['ID'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Resturants for each borough in New York City')
#On x-axis
plt.xlabel('Neighborhood', fontsize = 15)
#On y-axis
plt.ylabel('No.of Resturants', fontsize=15)
#giving a bar plot
rest_ny.groupby(['Borough','Name'])['ID'].count().nlargest(5).plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Resturants for each Neighborhood in New York City')
#On x-axis
plt.xlabel('Neighborhood', fontsize = 15)
#On y-axis
plt.ylabel('No.of Resturants', fontsize=15)
#giving a bar plot
rest_ny.groupby(['Borough','Neighborhood','Name'])['ID'].count().nlargest(5).plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
#rest_ny[rest_ny['Neighborhood']=='Murray Hill']

# %%
# prepare neighborhood list that contains resturants
column_names=['Borough', 'Neighborhood', 'Category', 'ID','Name','Likes','Rating','Tips']
rest_stats_ny=pd.DataFrame(columns=column_names)
count=1


for row in rest_ny.values.tolist():
    Borough,Neighborhood,ID,Name,Category=row
    try:
        print(ID)
        venue_details=get_venue_details(ID)
        time.sleep(1)
        #print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    except:
        print('Exception occured')
        continue
        
    print('(',count,'/',len(rest_ny),')','processed')
    rest_stats_ny = rest_stats_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'Category' : category,  
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1

# %% [markdown]
# From above we can see that there are 306 total different Neighborhoods in New York City in 5 boroughs.
# Queens has highes number of neighborhoods - 81
# Manhattan has - 40
# Bronx has - 52
# Brooklyn has - 70
# Staten Island - 63
#
# Bronx            52
# Brooklyn         70
# Manhattan        40
# Queens           81
# Staten Island    63
#
# Restaurants
# ==========
# Bronx             646
# Brooklyn         1332
# Manhattan        1100
# Queens           1400
# Staten Island     483

# %%
# of restaurants per neighborhood in each borough

print('In Bronx # of restaurants per neighborhood', 646/52)
print('In Brooklyn # of restaurants per neighborhood', 1332/70)
print('In Manhattan # of restaurants per neighborhood', 1100/40)
print('In Queens # of restaurants per neighborhood', 1400/81)
print('In Staten Island # of restaurants per neighborhood', 483/63)
# Out:
# In Bronx # of restaurants per neighborhood 12.423076923076923
# In Brooklyn # of restaurants per neighborhood 19.02857142857143
# In Manhattan # of restaurants per neighborhood 27.5
# In Queens # of restaurants per neighborhood 17.28395061728395
# In Staten Island # of restaurants per neighborhood 7.666666666666667

# %% [markdown]
# ### This indicates that Staten Island has the least # of restaurants per neighborhood.
#
# Now lets determine which category restaurant is well suited to start in Staten Island

# %%
rest_ny.groupby('Borough')['ID'].count()

# %%
column_names=['Borough', 'Neighborhood', 'Category', 'ID','Name','Likes','Rating','Tips']
rest_stats_ny=pd.DataFrame(columns=column_names)
count=1


for row in rest_ny.values.tolist():
    Borough,Neighborhood,ID,Name,Category=row
    try:
        print(ID)
        venue_details=get_venue_details(ID)
        time.sleep(1)
        #print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    except:
        print('Exception occured')
        continue
        
    print('(',count,'/',len(rest_ny),')','processed')
    rest_stats_ny = rest_stats_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'Category' : Category,  
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1

# %%
rest_stats_ny.to_csv('Borough_Restaurant_Ratings.csv')

# %%
rest_stats_ny.head()
# Out:
#   Borough Neighborhood                         Category  \
# 0   Bronx    Wakefield             Caribbean Restaurant
# 1   Bronx    Wakefield             Caribbean Restaurant
# 2   Bronx    Wakefield             Caribbean Restaurant
# 3   Bronx    Wakefield             Caribbean Restaurant
# 4   Bronx    Wakefield  Southern / Soul Food Restaurant
#
#                          ID                                     Name Likes  \
# 0  4d375ce799fe8eec99fd2355                       Ripe Kitchen & Bar    70
# 1  4c9e50e38afca09379b2ff15                          Ali's Roti Shop    16
# 2  4c10f6aece57c92804a682d2              Jackie's West Indian Bakery    22
# 3  508af256e4b0578944c87392  Cooler Runnings Jamaican Restaurant Inc     7
# 4  55bff8a5498e67af2457ca92                        Paula's Soul Cafe     5
#
#    Rating Tips
# 0     8.7   33
# 1     8.5    9
# 2     7.8   13
# 3     6.9    4
# 4     6.8    1

# %%
rest_stats_ny.groupby(['Borough','Category'])['ID'].count()
# Out:
# Borough    Category
# Bronx      African Restaurant                  4
#            American Restaurant                30
#            Arepa Restaurant                    2
#            Asian Restaurant                   13
#            Caribbean Restaurant               32
#            Chinese Restaurant                 50
#            Cuban Restaurant                    2
#            Dumpling Restaurant                 1
#            Eastern European Restaurant         1
#            Empanada Restaurant                 1
#            Fast Food Restaurant               75
#            French Restaurant                   1
#            Greek Restaurant                    3
#            Halal Restaurant                    1
#            Indian Restaurant                   3
#            Italian Restaurant                 74
#            Japanese Restaurant                 8
#            Latin American Restaurant          32
#            Mexican Restaurant                 52
#            Middle Eastern Restaurant           1
#            New American Restaurant             1
#            Paella Restaurant                   2
#            Peruvian Restaurant                 2
#            Restaurant                         16
#            Seafood Restaurant                 16
#            Southern / Soul Food Restaurant     3
#            Spanish Restaurant                 42
#            Sushi Restaurant                    9
#            Tapas Restaurant                    3
#            Thai Restaurant                     8
#            Theme Restaurant                    1
#            Vietnamese Restaurant               1
# Manhattan  American Restaurant                 1
#            Asian Restaurant                    1
#            Caribbean Restaurant                1
#            Chinese Restaurant                  2
#            Cuban Restaurant                    1
#            Mexican Restaurant                  3
#            Seafood Restaurant                  1
#            Spanish Restaurant                  3
#            Thai Restaurant                     1
# Name: ID, dtype: int64

# %%
rest_stats_ny.groupby(['Borough','Category'])['Rating'].sum()
# Out:
# Borough    Category
# Bronx      African Restaurant                  30.2
#            American Restaurant                192.4
#            Arepa Restaurant                    18.2
#            Asian Restaurant                    82.0
#            Caribbean Restaurant               229.6
#            Chinese Restaurant                 112.6
#            Cuban Restaurant                     8.8
#            Dumpling Restaurant                  8.1
#            Eastern European Restaurant          6.2
#            Empanada Restaurant                  7.2
#            Fast Food Restaurant               428.1
#            French Restaurant                    7.6
#            Greek Restaurant                    24.6
#            Halal Restaurant                     0.0
#            Indian Restaurant                   20.4
#            Italian Restaurant                 539.5
#            Japanese Restaurant                 61.3
#            Latin American Restaurant          174.0
#            Mexican Restaurant                 366.4
#            Middle Eastern Restaurant            7.8
#            New American Restaurant              6.9
#            Paella Restaurant                   15.0
#            Peruvian Restaurant                 17.6
#            Restaurant                          79.3
#            Seafood Restaurant                  92.6
#            Southern / Soul Food Restaurant     13.9
#            Spanish Restaurant                 258.6
#            Sushi Restaurant                    52.6
#            Tapas Restaurant                    27.0
#            Thai Restaurant                     58.7
#            Theme Restaurant                     7.7
#            Vietnamese Restaurant                7.8
# Manhattan  American Restaurant                  7.0
#            Asian Restaurant                     0.0
#            Caribbean Restaurant                 8.6
#            Chinese Restaurant                   0.0
#            Cuban Restaurant                     7.2
#            Mexican Restaurant                  24.4
#            Seafood Restaurant                   7.5
#            Spanish Restaurant                  14.3
#            Thai Restaurant                      7.1
# Name: Rating, dtype: float64

# %%
rest_stats_ny_avg = rest_stats_ny.groupby(['Borough','Category']).mean()[['Rating']]

# %%
rest_stats_ny_avg.head()
# Out:
#                                 Rating
# Borough Category
# Bronx   African Restaurant    7.550000
#         American Restaurant   6.413333
#         Arepa Restaurant      9.100000
#         Asian Restaurant      6.307692
#         Caribbean Restaurant  7.175000

# %% [markdown]
# ### Basing on below Arepa Restaurants or South American restaurant is a good option to start in Bronx

# %%
rest_stats_ny_avg.sort_values(['Rating'],ascending=False).head(10)
# Out:
#                                        Rating
# Borough   Category
# Bronx     Arepa Restaurant           9.100000
#           Tapas Restaurant           9.000000
#           Peruvian Restaurant        8.800000
# Manhattan Caribbean Restaurant       8.600000
# Bronx     Greek Restaurant           8.200000
# Manhattan Mexican Restaurant         8.133333
# Bronx     Dumpling Restaurant        8.100000
#           Vietnamese Restaurant      7.800000
#           Middle Eastern Restaurant  7.800000
#           Theme Restaurant           7.700000

# %%
ny_neighborhood_stats=pd.merge(rest_stats_ny_avg,new_york_data, on='Borough')

# %%
ny_neighborhood_stats.head()
# Out:
#   Borough  Rating Neighborhood   Latitude  Longitude
# 0   Bronx    7.55    Wakefield  40.894705 -73.847201
# 1   Bronx    7.55   Co-op City  40.874294 -73.829939
# 2   Bronx    7.55  Eastchester  40.887556 -73.827806
# 3   Bronx    7.55    Fieldston  40.895437 -73.905643
# 4   Bronx    7.55    Riverdale  40.890834 -73.912585

# %%
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)

# %%
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in ny_neighborhood_stats[['Latitude','Longitude']].values:
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# %%
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)
ny_geo = r'Borough Boundaries.geojson'

ny_map.choropleth(
    geo_data=ny_geo,
    data=ny_borough_stats,
    columns=['Borough', 'Average Rating'],
    key_on='feature.properties.boro_name',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Average Rating'
)

# display map
# as this is huge map data , we will save it to a file
ny_map.save('borough_rating.html')

# %%
ny_neighborhood_stats['Label']=ny_neighborhood_stats['Neighborhood']+', '+ny_neighborhood_stats['Borough']+'('+ny_neighborhood_stats['Rating'].map(str)+')'

# %%
#for lat, lng, label in ny_neighborhood_stats[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(ny_map)        
# add incidents to map
ny_map.add_child(incidents)

# %% [markdown]
# ### Conclusion
# Manhattan has more # of restaurants per neighborhood.
# Queens has the highest restaurants in a neighborhood (Korean)
# Staten Island has least number of restaurants
#
#
# ### Limitations
# The ranking is purely on basis of rating of resturants
# The accuracy of data depends purely depends on the data provided by FourSquare
# Foursquare limitation of retrieving restaurant details
